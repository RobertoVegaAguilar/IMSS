# %%
import numpy as np
import pandas as pd
import requests

# %%
#Lista de último día de mes. Funciona para leer los archivos y para agregar la columna 'Fecha'.
fecha=['2010-01-31',
 '2010-02-29',
 '2010-03-31',
 '2010-04-30',
 '2010-05-31',
 '2010-06-30',
 '2010-07-31',
 '2010-08-31',
 '2010-09-30',
 '2010-10-31',
 '2010-11-30',
 '2010-12-31',
 '2011-01-31',
 '2011-02-29',
 '2011-03-31',
 '2011-04-30',
 '2011-05-31',
 '2011-06-30',
 '2011-07-31',
 '2011-08-31',
 '2011-09-30',
 '2011-10-31',
 '2011-11-30',
 '2011-12-31',
 '2012-01-31',
 '2012-02-29',
 '2012-03-31',
 '2012-04-30',
 '2012-05-31',
 '2012-06-30',
 '2012-07-31',
 '2012-08-31',
 '2012-09-30',
 '2012-10-31',
 '2012-11-30',
 '2012-12-31',
 '2013-01-31',
 '2013-02-28',
 '2013-03-31',
 '2013-04-30',
 '2013-05-31',
 '2013-06-30',
 '2013-07-31',
 '2013-08-31',
 '2013-09-30',
 '2013-10-31',
 '2013-11-30',
 '2013-12-31',
 '2014-01-31',
 '2014-02-28',
 '2014-03-31',
 '2014-04-30',
 '2014-05-31',
 '2014-06-30',
 '2014-07-31',
 '2014-08-31',
 '2014-09-30',
 '2014-10-31',
 '2014-11-30',
 '2014-12-31',
 '2015-01-31',
 '2015-02-28',
 '2015-03-31',
 '2015-04-30',
 '2015-05-31',
 '2015-06-30',
 '2015-07-31',
 '2015-08-31',
 '2015-09-30',
 '2015-10-31',
 '2015-11-30',
 '2015-12-31',
 '2016-01-31',
 '2016-02-29',
 '2016-03-31',
 '2016-04-30',
 '2016-05-31',
 '2016-06-30',
 '2016-07-31',
 '2016-08-31',
 '2016-09-30',
 '2016-10-31',
 '2016-11-30',
 '2016-12-31',
 '2017-01-31',
 '2017-02-28',
 '2017-03-31',
 '2017-04-30',
 '2017-05-31',
 '2017-06-30',
 '2017-07-31',
 '2017-08-31',
 '2017-09-30',
 '2017-10-31',
 '2017-11-30',
 '2017-12-31',
 '2018-01-31',
 '2018-02-28',
 '2018-03-31',
 '2018-04-30',
 '2018-05-31',
 '2018-06-30',
 '2018-07-31',
 '2018-08-31',
 '2018-09-30',
 '2018-10-31',
 '2018-11-30',
 '2018-12-31',
 '2019-01-31',
 '2019-02-28',
 '2019-03-31',
 '2019-04-30',
 '2019-05-31',
 '2019-06-30',
 '2019-07-31',
 '2019-08-31',
 '2019-09-30',
 '2019-10-31',
 '2019-11-30',
 '2019-12-31',
 '2020-01-31',
 '2020-02-29',
 '2020-03-31',
 '2020-04-30',
 '2020-05-31',
 '2020-06-30',
 '2020-07-31',
 '2020-08-31',
 '2020-09-30',
 '2020-10-31',
 '2020-11-30',
 '2020-12-31',
 '2021-01-31',
 '2021-02-28',
 '2021-03-31',
 '2021-04-30',
 '2021-05-31',
 '2021-06-30',
 '2021-07-31',
 '2021-08-31',
 '2021-09-30',
 '2021-10-31',
 '2021-11-30',
 '2021-12-31',
 '2022-01-31',
 '2022-02-28',
 '2022-03-31',
 '2022-04-30',
 '2022-05-31',
 '2022-06-30',
 '2022-07-31',
 '2022-08-31',
 '2022-09-30',
 '2022-10-31',
 '2022-11-30',
 '2022-12-31',
 '2023-01-31',
 '2023-02-28',
 '2023-03-31',
 '2023-04-30',
 '2023-05-31',
 '2023-06-30',
 '2023-07-31',
 '2023-08-31']

# %%
# Crear lista de nombre de los archivos.
for i in range (len(fecha)):
    inicio='asg-'
    final='.csv'
    archivo[i]=inicio+fecha[i]+final
    archivo
archivo
# Out:
# ['asg-2010-01-31.csv',
#  'asg-2010-02-29.csv',
#  'asg-2010-03-31.csv',
#  'asg-2010-04-30.csv',
#  'asg-2010-05-31.csv',
#  'asg-2010-06-30.csv',
#  'asg-2010-07-31.csv',
#  'asg-2010-08-31.csv',
#  'asg-2010-09-30.csv',
#  'asg-2010-10-31.csv',
#  'asg-2010-11-30.csv',
#  'asg-2010-12-31.csv',
#  'asg-2011-01-31.csv',
#  'asg-2011-02-29.csv',
#  'asg-2011-03-31.csv',
#  'asg-2011-04-30.csv',
#  'asg-2011-05-31.csv',
#  'asg-2011-06-30.csv',
#  'asg-2011-07-31.csv',
#  'asg-2011-08-31.csv',
#  'asg-2011-09-30.csv',
#  'asg-2011-10-31.csv',
#  'asg-2011-11-30.csv',
#  'asg-2011-12-31.csv',
#  'asg-2012-01-31.csv',
#  'asg-2012-02-29.csv',
#  'asg-2012-03-31.csv',
#  'asg-2012-04-30.csv',
#  'asg-2012-05-31.csv',
#  'asg-2012-06-30.csv',
#  'asg-2012-07-31.csv',
#  'asg-2012-08-31.csv',
#  'asg-2012-09-30.csv',
#  'asg-2012-10-31.csv',
#  'asg-2012-11-30.csv',
#  'asg-2012-12-31.csv',
#  'asg-2013-01-31.csv',
#  'asg-2013-02-28.csv',
#  'asg-2013-03-31.csv',
#  'asg-2013-04-30.csv',
# ...

# %%
fecha
# Out:
# ['2010-01-31',
#  '2010-02-29',
#  '2010-03-31',
#  '2010-04-30',
#  '2010-05-31',
#  '2010-06-30',
#  '2010-07-31',
#  '2010-08-31',
#  '2010-09-30',
#  '2010-10-31',
#  '2010-11-30',
#  '2010-12-31',
#  '2011-01-31',
#  '2011-02-29',
#  '2011-03-31',
#  '2011-04-30',
#  '2011-05-31',
#  '2011-06-30',
#  '2011-07-31',
#  '2011-08-31',
#  '2011-09-30',
#  '2011-10-31',
#  '2011-11-30',
#  '2011-12-31',
#  '2012-01-31',
#  '2012-02-29',
#  '2012-03-31',
#  '2012-04-30',
#  '2012-05-31',
#  '2012-06-30',
#  '2012-07-31',
#  '2012-08-31',
#  '2012-09-30',
#  '2012-10-31',
#  '2012-11-30',
#  '2012-12-31',
#  '2013-01-31',
#  '2013-02-28',
#  '2013-03-31',
#  '2013-04-30',
#  '2013-05-31',
#  '2013-06-30',
#  '2013-07-31',
#  '2013-08-31',
#  '2013-09-30',
#  '2013-10-31',
#  '2013-11-30',
#  '2013-12-31',
#  '2014-01-31',
#  '2014-02-28',
#  '2014-03-31',
#  '2014-04-30',
#  '2014-05-31',
#  '2014-06-30',
#  '2014-07-31',
#  '2014-08-31',
#  '2014-09-30',
#  '2014-10-31',
# ...

# %%
len(archivo)
# Out:
# 164

# %%
#Realiza el filtrado de Jalisco. la columna 'cve_entidad' debe ser igual a 14 (código para Jalisco). El rango del ciclo es igual a el tamaño de la lista archivo.
dataframes_filtrados = []
for i in range(0,164):
    df=pd.read_csv(archivo[i], sep="|", header='infer', encoding='latin-1',low_memory=False)
    df_filtrado = df[df['cve_entidad'] == 14].copy()
    df_filtrado.loc[:,'Fecha']=fecha[i]
    dataframes_filtrados.append(df_filtrado)
resultado = pd.concat(dataframes_filtrados, ignore_index=True)
print(resultado)
# Out:
#         cve_delegacion  cve_subdelegacion  cve_entidad cve_municipio  \
# 0                   14                 12           14           B80
# 1                   14                 12           14           B80
# 2                   14                 12           14           B80
# 3                   14                 12           14           B80
# 4                   14                 12           14           B80
# ...                ...                ...          ...           ...
# 599413              14                 50           14           S28
# 599414              14                 50           14           S28
# 599415              14                 50           14           S28
# 599416              14                 50           14           S28
# 599417              14                 50           14           S28
#
#         sector_economico_1  sector_economico_2  sector_economico_4  \
# 0                      NaN                 NaN                 NaN
# ...

# %%
resultado
# Out:
#         cve_delegacion  cve_subdelegacion  cve_entidad cve_municipio  \
# 0                   14                 12           14           B80
# 1                   14                 12           14           B80
# 2                   14                 12           14           B80
# 3                   14                 12           14           B80
# 4                   14                 12           14           B80
# ...                ...                ...          ...           ...
# 599413              14                 50           14           S28
# 599414              14                 50           14           S28
# 599415              14                 50           14           S28
# 599416              14                 50           14           S28
# 599417              14                 50           14           S28
#
#         sector_economico_1  sector_economico_2  sector_economico_4  \
# 0                      NaN                 NaN                 NaN
# ...
